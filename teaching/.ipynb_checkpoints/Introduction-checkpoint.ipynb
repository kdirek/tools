# %% [markdown]
# # Introduction to R

# %% [markdown]
# R is a open-source programming language for statistical computing 1; it is derived from another programming language - S, which was developed in 1976 at the world-renowned Bell laboratories.

# %% [markdown]
# R's ability to implement a wide and constantly expanding catalogue of statistical models differs from other statistical programmes in that it allows users to write and compile their own mathematical functions, or suite of functions known as packages.

# %% [markdown]
# Packages can be submitted to the core team, who perform checks on the integrity and functionality of user submitted packages, those that pass this quality control stage are stored in the Comprehensive R Archive Network (CRAN) repository -  a global network of FTP mirror sites, totalling  104 sites in 49 countries.

# %% [markdown]
# In the United Kingdom, five academic institutions host the CRAN:
#
# 1.	School of Mathematics, University of Bristol
# 2.	European Bioinformatics Institute, Wellcome Trust Genome Campus
# 3.	Department of Mathematics, Imperial College London
# 4.	Computer Science Department, Middlesex University London
# 5.	School of Physics and Astronomy, University of St Andrews

# %% [markdown]
# There are currently 6,367 packages available in CRAN, in addition various other repositories have been created for specific applications, for example, the Bioconductor  project2 contains 934 packages for the analysis of genomic data. R's popularity in academia has extended into large-scale corporate business and government agencies because it provides the latest tools available for data analysis at zero cost.

# %% [markdown]
# Why use it?
# * Free
# * Well developed and effective programming language
# * Powerful suite of tools that is well-documented
# * Good online support
# * It comes in a variety of forms - available for all major operating systems and can be run on desktops and high performance computing clusters

# %% [markdown]
# ## *Basic Operations*

# %% [markdown]
# At the most basic level you can use it as a calculator:

# %%
1 + 2
# Out:
# [1] 3

# %% [markdown]
# It allows you to assign a value to a named data structure (object):

# %%
a <- 1
b <- 2
a + b
# Out:
# [1] 3

# %% [markdown]
# You can assign a number of values (a vector) to an object:

# %%
a <- c(1,2,3,4,5)
b <- c(1, 1e1, 1e2, 1e3, 1e4)
a * b
# Out:
# [1]     1    20   300  4000 50000

# %% [markdown]
# Instead of numbers, you can supply characters to objects:

# %%
first.name <- c("Homer", "Peter", "Francine")
last.name <- c("Simpson", "Griffin", "Smith")
paste(first.name, last.name, sep = " ")
# Out:
# [1] "Homer Simpson"  "Peter Griffin"  "Francine Smith"

# %% [markdown]
# ## *Moving Around*

# %% [markdown]
# An important concept to grasp if you are new to programming is the working directory. As its name suggests, it is the directory (think folder) where you store files to be analysed and can save objects you created in R.

# %% [markdown]
# Our first example used the paste function to combine two character vectors (first and last names),
# we can also use this function to move around folders from within R. This because especially useful
# if you want your script to write output to be written in particular folders, e.g. by gender or
# ethnicity.

# %% [markdown]
# When you first open R the default working directory is normally the folder where the R library is saved. You can find out by typing:

# %%
getwd()
# Out:
# [1] "C:/Users/ucbtkdi"

# %% [markdown]
# Normally the files you want to analyse are not the default folder. This is not just good practice organising your data but also you may find the data is on a restricted location, e.g. a network drive, and cannot move the data for security reasons. You can set the working directory at any time during your R session, simply tell R where you want the working directory to be:

# %%
setwd("C:/Users/ucbtkdi/temp")

# %%
getwd()
# Out:
# [1] "C:/Users/ucbtkdi/temp"

# %% [markdown]
# ## *Data Storage Types*

# %% [markdown]
# R stores data in a form that it thinks is most appropriate, there are several types it can select from:

# %% [markdown]
# * logical - TRUE/FALSE
# * numeric
#     + integer - 1,2,3,4,5
#     + single/double precision - 32 and 64 bit precision
#     + complex - 1 + 0i
# * character - "hello"
# * symbol - the name of an object

# %% [markdown]
# ## *Getting Data into R*

# %% [markdown]
# You will normally get data into R from external files or locations, for example,

# %%
data1 <- read.table("test.csv", head = T, sep = ",")

# %% [markdown]
# The function "read.table" is one of several related functions in R that allows you to read in data. Others are read.csv and read.delim for comma and tab seperated files. All accept a predefined list of options that you can specify, to understand more about the function you can use R's in-built help system:

# %%
help("read.table")

# %% [markdown]
# One of the options with read.table is to select the value that seperates columns in your dataset. If you are reading in comma seperated value (csv) files, use the read.csv function as it save you some typing.

# %% [markdown]
# If you are given data in a workbook (.xls/x), you will need to call on function from a package (called "xlsx").

# %%
library("xlsx")
data.xlsx <- read.xlsx(file = "test_excelfile.xlsx", sheetIndex = 1)

# %% [markdown]
# To read in large files efficiently, another specialised function must be
# called this time from the "data.table" package.

# %%
data <- data.table::fread("big_file.csv")

# %% [markdown]
# ## *Data Structures*

# %% [markdown]
# R normally reads data into structures called data.frames. A data.frame is a very useful object in that it allows you to mix vectors of different types (numeric, character, etc.). It is an organised list of vectors, each column of your dataset in stored as an individual vector. The data.frame is displayed as a 2 dimensional array with rows and columns and can be indexed:

# %%
head(data) # look at the first 6 rows
data.xlsx[1:6,]

# %% [markdown]
# A related structure is a matrix, again a 2 dimensional array that can be indexed, but all columns must be of the same type. These are particularly useful when storing the output of a statistical analysis.

# %%
the.matrix <- matrix(c(1:9), nrow = 3, ncol = 3) # put numbers 1-9 into a 3 by 3 matrix
the.matrix
now.dataframe <- as.data.frame(the.matrix)
# Out:
#      [,1] [,2] [,3]
# [1,] 1    4    7
# [2,] 2    5    8
# [3,] 3    6    9

# %% [markdown]
# Can always convert a matrix into a data.frame, to go the other way, the columns of the data.frame must be of the same type.

# %% [markdown]
# A list is an ordered collection of components, these components can be anything, e.g. numbers, strings, data.frames, other lists(!).

# %%
new.list <- list(Forename = first.name, 
                 Surname = last.name, 
                 'Date of Birth' = c("1950-01-30", "1960-05-20", "1955-09-10"), 
                 PracID = c(100,NA,450))
new.list
# Out:
# $Forename
# [1] "Homer"    "Peter"    "Francine"
#
# $Surname
# [1] "Simpson" "Griffin" "Smith"
#
# $`Date of Birth`
# [1] "1950-01-30" "1960-05-20" "1955-09-10"
#
# $PracID
# [1] 100  NA 450

# %% [markdown]
# Lists are a good way of storing many objects without clutering your workspace, for example, say you had 1,000 csv files in a folder and wanted to read them all into R:

# %%
# for(i in 1:1e3){
# write.csv(data.frame(patid = sample(1e3, 10), height = sample(150:200, 10), weight = sample(60:120,10)), file = paste0("file_", i, ".csv"))
# }

# %%
list.myfilenames <- list.files(getwd(), pattern = "\\.csv$") # get the names of the files you want
list.myfiles <- lapply(setNames(list.myfilenames, make.names(gsub("*.csv$", "", list.myfilenames))), read.csv) # read them in
lapply(list.myfiles[1:10], head) # check a couple

# %% [markdown]
# ## *Getting Help*

# %%
?read.csv
help("read.csv")

# %% [markdown]
# This will do one of several things depending on the operating system and internet connection status; it will open your browser on the GUI version, open a new window within your session if you're not connected to the internet, or if you're working on a server it will print the help file to the command line. The help files usually give an example of the function for you to see how it should work.

# %% [markdown]
# To see an example of the function in action if it exists, you can use 'example':

# %%
example(summary)
# Out:
# summry> summary(attenu, digits = 4) #-> summary.data.frame(...), default precision
#      event            mag           station         dist
#  Min.   : 1.00   Min.   :5.000   117    :  5   Min.   :  0.50
#  1st Qu.: 9.00   1st Qu.:5.300   1028   :  4   1st Qu.: 11.32
#  Median :18.00   Median :6.100   113    :  4   Median : 23.40
#  Mean   :14.74   Mean   :6.084   112    :  3   Mean   : 45.60
#  3rd Qu.:20.00   3rd Qu.:6.600   135    :  3   3rd Qu.: 47.55
#  Max.   :23.00   Max.   :7.700   (Other):147   Max.   :370.00
#                                  NA's   : 16
#      accel
#  Min.   :0.00300
#  1st Qu.:0.04425
#  Median :0.11300
#  Mean   :0.15422
#  3rd Qu.:0.21925
#  Max.   :0.81000
#
#
# summry> summary(attenu $ station, maxsum = 20) #-> summary.factor(...)
#     117    1028     113     112     135     475    1030    1083    1093    1095
#       5       4       4       3       3       3       2       2       2       2
#     111     116    1219    1299     130    1308    1377    1383 (Other)    NA's
#       2       2       2       2       2       2       2       2     120      16
#
# summry> lst <- unclass(attenu$station) > 20 # logical with NAs
#
# summry> ## summary.default() for logicals -- different from *.factor:
# summry> summary(lst)
#    Mode   FALSE    TRUE    NA's
# logical      28     138      16
#
# summry> summary(as.factor(lst))
# FALSE  TRUE  NA's
#    28   138    16

# %% [markdown]
# ## *Libraries*

# %% [markdown]
# Like we've done above to read in and out files, functions from packages must first be loaded into our R session. Thankfully, you don't have to install every package each time you install R, to see what packages you already have type:

# %%
installed.packages()
# Out:
#              Package      LibPath
# colorspace   colorspace   /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# crayon       crayon       /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# curl         curl         /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# devtools     devtools     /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# dichromat    dichromat    /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# digest       digest       /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# evaluate     evaluate     /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# gdata        gdata        /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# ggplot2      ggplot2      /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# git2r        git2r        /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# gtable       gtable       /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# gtools       gtools       /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# httpuv       httpuv       /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# httr         httr         /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# IRdisplay    IRdisplay    /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# IRkernel     IRkernel     /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# jsonlite     jsonlite     /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# labeling     labeling     /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# lazyeval     lazyeval     /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# magrittr     magrittr     /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# memoise      memoise      /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# mime         mime         /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# munsell      munsell      /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# openssl      openssl      /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# pbdZMQ       pbdZMQ       /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# plyr         plyr         /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# praise       praise       /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# R6           R6           /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# RColorBrewer RColorBrewer /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# Rcpp         Rcpp         /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# ⋮            ⋮            ⋮
# zoo          zoo          /home/kenan/R/x86_64-pc-linux-gnu-library/3.2
# base         base         /usr/lib/R/library
# boot         boot         /usr/lib/R/library
# class        class        /usr/lib/R/library
# cluster      cluster      /usr/lib/R/library
# codetools    codetools    /usr/lib/R/library
# compiler     compiler     /usr/lib/R/library
# datasets     datasets     /usr/lib/R/library
# foreign      foreign      /usr/lib/R/library
# graphics     graphics     /usr/lib/R/library
# grDevices    grDevices    /usr/lib/R/library
# grid         grid         /usr/lib/R/library
# KernSmooth   KernSmooth   /usr/lib/R/library
# lattice      lattice      /usr/lib/R/library
# MASS         MASS         /usr/lib/R/library
# Matrix       Matrix       /usr/lib/R/library
# methods      methods      /usr/lib/R/library
# mgcv         mgcv         /usr/lib/R/library
# nlme         nlme         /usr/lib/R/library
# nnet         nnet         /usr/lib/R/library
# parallel     parallel     /usr/lib/R/library
# rpart        rpart        /usr/lib/R/library
# spatial      spatial      /usr/lib/R/library
# splines      splines      /usr/lib/R/library
# stats        stats        /usr/lib/R/library
# stats4       stats4       /usr/lib/R/library
# survival     survival     /usr/lib/R/library
# tcltk        tcltk        /usr/lib/R/library
# tools        tools        /usr/lib/R/library
# utils        utils        /usr/lib/R/library
#              Version     Priority
# colorspace   1.3-2       NA
# crayon       1.3.4       NA
# curl         3.0         NA
# devtools     1.13.3      NA
# dichromat    2.0-0       NA
# digest       0.6.12      NA
# evaluate     0.10.1      NA
# gdata        2.18.0      NA
# ggplot2      2.2.1       NA
# git2r        0.19.0      NA
# gtable       0.2.0       NA
# gtools       3.5.0       NA
# httpuv       1.3.5       NA
# httr         1.3.1       NA
# IRdisplay    0.4.4       NA
# IRkernel     0.8.12.9000 NA
# jsonlite     1.5         NA
# labeling     0.3         NA
# lazyeval     0.2.1       NA
# magrittr     1.5         NA
# memoise      1.1.0       NA
# mime         0.5         NA
# munsell      0.4.3       NA
# openssl      0.9.8       NA
# pbdZMQ       0.2-6       NA
# plyr         1.8.4       NA
# praise       1.0.0       NA
# R6           2.2.2       NA
# RColorBrewer 1.1-2       NA
# Rcpp         0.12.13     NA
# ⋮            ⋮           ⋮
# zoo          1.8-0       NA
# base         3.2.3       base
# boot         1.3-17      recommended
# class        7.3-14      recommended
# cluster      2.0.3       recommended
# codetools    0.2-14      recommended
# compiler     3.2.3       base
# datasets     3.2.3       base
# foreign      0.8-66      recommended
# graphics     3.2.3       base
# grDevices    3.2.3       base
# grid         3.2.3       base
# KernSmooth   2.23-15     recommended
# lattice      0.20-33     recommended
# MASS         7.3-45      recommended
# Matrix       1.2-3       recommended
# methods      3.2.3       base
# mgcv         1.8-11      recommended
# nlme         3.1-124     recommended
# nnet         7.3-12      recommended
# parallel     3.2.3       base
# rpart        4.1-10      recommended
# spatial      7.3-11      recommended
# splines      3.2.3       base
# stats        3.2.3       base
# stats4       3.2.3       base
# survival     2.38-3      recommended
# tcltk        3.2.3       base
# tools        3.2.3       base
# utils        3.2.3       base
#              Depends
# colorspace   R (>= 2.13.0), methods
# crayon       NA
# curl         R (>= 3.0.0)
# devtools     R (>= 3.0.2)
# dichromat    R (>= 2.10), stats
# digest       R (>= 2.4.1)
# evaluate     R (>= 3.0.2)
# gdata        R (>= 2.3.0)
# ggplot2      R (>= 3.1)
# git2r        R (>= 3.0.2), methods
# gtable       R (>= 2.14)
# gtools       R (>= 2.10)
# httpuv       R (>= 2.15.1), methods
# httr         R (>= 3.0.0)
# IRdisplay    R (>= 3.0.1)
# IRkernel     \nR (>= 3.2.0)
# jsonlite     methods
# labeling     NA
# lazyeval     R (>= 3.1.0)
# magrittr     NA
# memoise      NA
# mime         NA
# munsell      NA
# openssl      NA
# pbdZMQ       R (>= 3.2.0)
# plyr         R (>= 3.1.0)
# praise       NA
# R6           R (>= 3.0)
# RColorBrewer R (>= 2.0.0)
# Rcpp         R (>= 3.0.0)
# ⋮            ⋮
# zoo          R (>= 2.10.0), stats
# base         NA
# boot         R (>= 3.0.0), graphics, stats
# class        R (>= 3.0.0), stats, utils
# cluster      R (>= 2.15.0), utils
# codetools    R (>= 2.1)
# compiler     NA
# datasets     NA
# foreign      R (>= 3.0.0)
# graphics     NA
# grDevices    NA
# grid         NA
# KernSmooth   R (>= 2.5.0), stats
# lattice      R (>= 3.0.0)
# MASS         R (>= 3.1.0), grDevices, graphics, stats, utils
# Matrix       R (>= 3.0.1)
# methods      NA
# mgcv         R (>= 2.14.0), nlme (>= 3.1-64)
# nlme         graphics, stats, R (>= 3.0.2)
# nnet         R (>= 2.14.0), stats, utils
# parallel     NA
# rpart        R (>= 2.15.0), graphics, stats, grDevices
# spatial      R (>= 3.0.0), graphics, stats, utils
# splines      NA
# stats        NA
# stats4       NA
# survival     R (>= 2.13.0), graphics, stats
# tcltk        NA
# tools        NA
# utils        NA
#              Imports
# colorspace   graphics, grDevices
# crayon       grDevices, methods, utils
# curl         NA
# devtools     httr (>= 0.4), utils, tools, methods, memoise (>= 1.0.0),\nwhisker, digest, rstudioapi (>= 0.2.0), jsonlite, stats, git2r\n(>= 0.11.0), withr
# dichromat    NA
# digest       NA
# evaluate     methods, stringr (>= 0.6.2)
# gdata        gtools, stats, methods, utils
# ggplot2      digest, grid, gtable (>= 0.1.1), MASS, plyr (>= 1.7.1),\nreshape2, scales (>= 0.4.1), stats, tibble, lazyeval
# git2r        graphics, utils
# gtable       grid
# gtools       NA
# httpuv       Rcpp (>= 0.11.0), utils
# httr         jsonlite, mime, curl (>= 0.9.1), openssl (>= 0.8), R6
# IRdisplay    repr
# IRkernel     \nrepr (>= 0.4.99),\nmethods,\nevaluate (>= 0.10),\nIRdisplay (>= 0.3.0.9999),\npbdZMQ (>= 0.2-1),\ncrayon,\njsonlite (>= 0.9.6),\nuuid,\ndigest
# jsonlite     NA
# labeling     NA
# lazyeval     NA
# magrittr     NA
# memoise      digest (>= 0.6.3)
# mime         tools
# munsell      colorspace, methods
# openssl      NA
# pbdZMQ       R6
# plyr         Rcpp (>= 0.11.0)
# praise       NA
# R6           NA
# RColorBrewer NA
# Rcpp         methods, utils
# ⋮            ⋮
# zoo          utils, graphics, grDevices, lattice (>= 0.20-27)
# base         NA
# boot         NA
# class        MASS
# cluster      graphics, grDevices, stats
# codetools    NA
# compiler     NA
# datasets     NA
# foreign      methods, utils, stats
# graphics     grDevices
# grDevices    NA
# grid         grDevices
# KernSmooth   NA
# lattice      grid, grDevices, graphics, stats, utils
# MASS         methods
# Matrix       methods, graphics, grid, stats, utils, lattice
# methods      utils
# mgcv         methods, stats, graphics, Matrix
# nlme         utils, lattice
# nnet         NA
# parallel     tools
# rpart        NA
# spatial      NA
# splines      graphics, stats
# stats        NA
# stats4       graphics, methods, stats
# survival     splines, methods
# tcltk        utils
# tools        NA
# utils        NA
#              LinkingTo
# colorspace   NA
# crayon       NA
# curl         NA
# devtools     NA
# dichromat    NA
# digest       NA
# evaluate     NA
# gdata        NA
# ggplot2      NA
# git2r        NA
# gtable       NA
# gtools       NA
# httpuv       Rcpp
# httr         NA
# IRdisplay    NA
# IRkernel     NA
# jsonlite     NA
# labeling     NA
# lazyeval     NA
# magrittr     NA
# memoise      NA
# mime         NA
# munsell      NA
# openssl      NA
# pbdZMQ       NA
# plyr         Rcpp
# praise       NA
# R6           NA
# RColorBrewer NA
# Rcpp         NA
# ⋮            ⋮
# zoo          NA
# base         NA
# boot         NA
# class        NA
# cluster      NA
# codetools    NA
# compiler     NA
# datasets     NA
# foreign      NA
# graphics     NA
# grDevices    NA
# grid         NA
# KernSmooth   NA
# lattice      NA
# MASS         NA
# Matrix       NA
# methods      NA
# mgcv         NA
# nlme         NA
# nnet         NA
# parallel     NA
# rpart        NA
# spatial      NA
# splines      NA
# stats        NA
# stats4       NA
# survival     NA
# tcltk        NA
# tools        NA
# utils        NA
#              Suggests
# colorspace   datasets, stats, utils, KernSmooth, MASS, kernlab, mvtnorm,\nvcd, dichromat, tcltk, shiny, shinyjs
# crayon       mockery, rstudioapi, testthat, withr
# curl         testthat (>= 1.0.0), knitr, jsonlite, rmarkdown, magrittr,\nhttpuv, webutils
# devtools     curl (>= 0.9), crayon, testthat (>= 1.0.2), BiocInstaller,\nRcpp (>= 0.10.0), MASS, rmarkdown, knitr, hunspell (>= 2.0),\nlintr (>= 0.2.1), bitops, roxygen2 (>= 5.0.0), evaluate,\nrversions, covr, gmailr (> 0.7.0)
# dichromat    NA
# digest       knitr, rmarkdown
# evaluate     testthat, lattice, ggplot2
# gdata        RUnit
# ggplot2      covr, ggplot2movies, hexbin, Hmisc, lattice, mapproj, maps,\nmaptools, mgcv, multcomp, nlme, testthat (>= 0.11.0), quantreg,\nknitr, rpart, rmarkdown, svglite
# git2r        getPass
# gtable       testthat, covr
# gtools       NA
# httpuv       NA
# httr         httpuv, jpeg, knitr, png, testthat (>= 0.8.0), readr, xml2,\nrmarkdown, covr
# IRdisplay    testthat, withr
# IRkernel     \ntestthat,\nroxygen2
# jsonlite     httr, curl, plyr, testthat, knitr, rmarkdown, R.rsp, sp
# labeling     NA
# lazyeval     knitr, rmarkdown (>= 0.2.65), testthat, covr
# magrittr     testthat, knitr
# memoise      testthat, aws.s3, httr, covr
# mime         NA
# munsell      ggplot2, testthat
# openssl      testthat, digest, knitr, rmarkdown, jsonlite, jose
# pbdZMQ       pbdRPC
# plyr         abind, testthat, tcltk, foreach, doParallel, itertools,\niterators, covr
# praise       testthat
# R6           knitr, microbenchmark, pryr, testthat, ggplot2, scales
# RColorBrewer NA
# Rcpp         RUnit, inline, rbenchmark, knitr, rmarkdown, pinp, pkgKitten\n(>= 0.1.2)
# ⋮            ⋮
# zoo          coda, chron, DAAG, fts, ggplot2, mondate, scales,\nstrucchange, timeDate, timeSeries, tis, tseries, xts
# base         methods
# boot         MASS, survival
# class        NA
# cluster      MASS
# codetools    NA
# compiler     NA
# datasets     NA
# foreign      NA
# graphics     NA
# grDevices    KernSmooth
# grid         lattice
# KernSmooth   MASS
# lattice      KernSmooth, MASS
# MASS         lattice, nlme, nnet, survival
# Matrix       expm, MASS
# methods      codetools
# mgcv         splines, parallel, survival, MASS
# nlme         Hmisc, MASS
# nnet         MASS
# parallel     methods
# rpart        survival
# spatial      MASS
# splines      Matrix, methods
# stats        MASS, Matrix, SuppDists, methods, stats4
# stats4       NA
# survival     cmprsk
# tcltk        NA
# tools        XML, codetools, methods
# utils        methods
#              Enhances
# colorspace   NA
# crayon       NA
# curl         NA
# devtools     NA
# dichromat    NA
# digest       NA
# evaluate     NA
# gdata        NA
# ggplot2      sp
# git2r        NA
# gtable       NA
# gtools       NA
# httpuv       NA
# httr         NA
# IRdisplay    NA
# IRkernel     NA
# jsonlite     NA
# labeling     NA
# lazyeval     NA
# magrittr     NA
# memoise      NA
# mime         NA
# munsell      NA
# openssl      NA
# pbdZMQ       remoter, pbdMPI
# plyr         NA
# praise       NA
# R6           NA
# RColorBrewer NA
# Rcpp         NA
# ⋮            ⋮
# zoo          NA
# base         NA
# boot         NA
# class        NA
# cluster      NA
# codetools    NA
# compiler     NA
# datasets     NA
# foreign      NA
# graphics     NA
# grDevices    NA
# grid         NA
# KernSmooth   NA
# lattice      chron
# MASS         NA
# Matrix       MatrixModels, graph, SparseM, sfsmisc
# methods      NA
# mgcv         NA
# nlme         NA
# nnet         NA
# parallel     snow, nws, Rmpi
# rpart        NA
# spatial      NA
# splines      NA
# stats        NA
# stats4       NA
# survival     NA
# tcltk        NA
# tools        NA
# utils        NA
#              License                        License_is_FOSS
# colorspace   BSD_3_clause + file LICENSE    NA
# crayon       MIT + file LICENSE             NA
# curl         MIT + file LICENSE             NA
# devtools     GPL (>= 2)                     NA
# dichromat    GPL-2                          NA
# digest       GPL (>= 2)                     NA
# evaluate     MIT + file LICENSE             NA
# gdata        GPL-2                          NA
# ggplot2      GPL-2 | file LICENSE           NA
# git2r        GPL-2                          NA
# gtable       GPL-2                          NA
# gtools       GPL-2                          NA
# httpuv       GPL-3 | file LICENSE           NA
# httr         MIT + file LICENSE             NA
# IRdisplay    MIT + file LICENSE             NA
# IRkernel     MIT + file LICENSE             NA
# jsonlite     MIT + file LICENSE             NA
# labeling     MIT + file LICENSE | Unlimited NA
# lazyeval     GPL-3                          NA
# magrittr     MIT + file LICENSE             NA
# memoise      MIT + file LICENSE             NA
# mime         GPL                            NA
# munsell      MIT + file LICENSE             NA
# openssl      MIT + file LICENSE             NA
# pbdZMQ       GPL-3                          NA
# plyr         MIT + file LICENSE             NA
# praise       MIT + file LICENSE             NA
# R6           MIT + file LICENSE             NA
# RColorBrewer Apache License 2.0             NA
# Rcpp         GPL (>= 2)                     NA
# ⋮            ⋮                              ⋮
# zoo          GPL-2 | GPL-3                  NA
# base         Part of R 3.2.3                NA
# boot         Unlimited                      NA
# class        GPL-2 | GPL-3                  NA
# cluster      GPL (>= 2)                     NA
# codetools    GPL                            NA
# compiler     Part of R 3.2.3                NA
# datasets     Part of R 3.2.3                NA
# foreign      GPL (>= 2)                     NA
# graphics     Part of R 3.2.3                NA
# grDevices    Part of R 3.2.3                NA
# grid         Part of R 3.2.3                NA
# KernSmooth   Unlimited                      NA
# lattice      GPL (>= 2)                     NA
# MASS         GPL-2 | GPL-3                  NA
# Matrix       GPL (>= 2)                     NA
# methods      Part of R 3.2.3                NA
# mgcv         GPL (>= 2)                     NA
# nlme         GPL (>= 2)                     NA
# nnet         GPL-2 | GPL-3                  NA
# parallel     Part of R 3.2.3                NA
# rpart        GPL-2 | GPL-3                  NA
# spatial      GPL-2 | GPL-3                  NA
# splines      Part of R 3.2.3                NA
# stats        Part of R 3.2.3                NA
# stats4       Part of R 3.2.3                NA
# survival     LGPL (>= 2)                    NA
# tcltk        Part of R 3.2.3                NA
# tools        Part of R 3.2.3                NA
# utils        Part of R 3.2.3                NA
#              License_restricts_use OS_type MD5sum NeedsCompilation Built
# colorspace   NA                    NA      NA     yes              3.2.3
# crayon       NA                    NA      NA     no               3.2.3
# curl         NA                    NA      NA     yes              3.2.3
# devtools     NA                    NA      NA     no               3.2.3
# dichromat    NA                    NA      NA     NA               3.2.3
# digest       NA                    NA      NA     yes              3.2.3
# evaluate     NA                    NA      NA     no               3.2.3
# gdata        NA                    NA      NA     no               3.2.3
# ggplot2      NA                    NA      NA     no               3.2.3
# git2r        NA                    NA      NA     yes              3.2.3
# gtable       NA                    NA      NA     no               3.2.3
# gtools       NA                    NA      NA     yes              3.2.3
# httpuv       NA                    NA      NA     yes              3.2.3
# httr         NA                    NA      NA     no               3.2.3
# IRdisplay    NA                    NA      NA     no               3.2.3
# IRkernel     NA                    NA      NA     NA               3.2.3
# jsonlite     NA                    NA      NA     yes              3.2.3
# labeling     NA                    NA      NA     no               3.2.3
# lazyeval     NA                    NA      NA     yes              3.2.3
# magrittr     NA                    NA      NA     no               3.2.3
# memoise      NA                    NA      NA     no               3.2.3
# mime         NA                    NA      NA     yes              3.2.3
# munsell      NA                    NA      NA     no               3.2.3
# openssl      NA                    NA      NA     yes              3.2.3
# pbdZMQ       NA                    NA      NA     yes              3.2.3
# plyr         NA                    NA      NA     yes              3.2.3
# praise       NA                    NA      NA     no               3.2.3
# R6           NA                    NA      NA     no               3.2.3
# RColorBrewer NA                    NA      NA     no               3.2.3
# Rcpp         NA                    NA      NA     yes              3.2.3
# ⋮            ⋮                     ⋮       ⋮      ⋮                ⋮
# zoo          NA                    NA      NA     yes              3.2.3
# base         NA                    NA      NA     NA               3.2.3
# boot         NA                    NA      NA     no               3.2.1
# class        NA                    NA      NA     yes              3.2.2
# cluster      NA                    NA      NA     yes              3.2.1
# codetools    NA                    NA      NA     no               3.2.1
# compiler     NA                    NA      NA     NA               3.2.3
# datasets     NA                    NA      NA     NA               3.2.3
# foreign      NA                    NA      NA     yes              3.2.2
# graphics     NA                    NA      NA     NA               3.2.3
# grDevices    NA                    NA      NA     NA               3.2.3
# grid         NA                    NA      NA     NA               3.2.3
# KernSmooth   NA                    NA      NA     yes              3.2.1
# lattice      NA                    NA      NA     yes              3.2.1
# MASS         NA                    NA      NA     yes              3.2.2
# Matrix       NA                    NA      NA     yes              3.2.2
# methods      NA                    NA      NA     NA               3.2.3
# mgcv         NA                    NA      NA     yes              3.2.3
# nlme         NA                    NA      NA     yes              3.2.3
# nnet         NA                    NA      NA     yes              3.2.3
# parallel     NA                    NA      NA     NA               3.2.3
# rpart        NA                    NA      NA     yes              3.2.1
# spatial      NA                    NA      NA     yes              3.2.2
# splines      NA                    NA      NA     NA               3.2.3
# stats        NA                    NA      NA     NA               3.2.3
# stats4       NA                    NA      NA     NA               3.2.3
# survival     NA                    NA      NA     yes              3.2.1
# tcltk        NA                    NA      NA     NA               3.2.3
# tools        NA                    NA      NA     NA               3.2.3
# utils        NA                    NA      NA     NA               3.2.3

# %% [markdown]
# If you need a package that is not installed on your system, you can install it:

# %%
install.packages("ggplot2")

# %% [markdown]
# Similarly, to remove a package:

# %%
remove.packages("ggplot2")

# %% [markdown]
# R has many built in functions, you can see them all in one place:

# %%
 builtins()
# Out:
#    [1] "zapsmall"                           "xzfile"
#    [3] "xtfrm.Surv"                         "xtfrm.POSIXlt"
#    [5] "xtfrm.POSIXct"                      "xtfrm.numeric_version"
#    [7] "xtfrm.factor"                       "xtfrm.difftime"
#    [9] "xtfrm.default"                      "xtfrm.Date"
#   [11] "xtfrm.AsIs"                         "xtfrm"
#   [13] "xpdrows.data.frame"                 "xor.octmode"
#   [15] "xor.hexmode"                        "xor"
#   [17] "%x%"                                "writeLines"
#   [19] "write.dcf"                          "writeChar"
#   [21] "writeBin"                           "write"
#   [23] "withVisible"                        "withRestarts"
#   [25] "within.list"                        "within.data.frame"
#   [27] "within"                             "with.default"
#   [29] "withCallingHandlers"                "with"
#   [31] "while"                              "which.min"
#   [33] "which.max"                          "which"
#   [35] "weekdays.POSIXt"                    "weekdays.Date"
#   [37] "weekdays"                           "[.warnings"
#   [39] "warnings"                           "warning"
#   [41] "version"                            "Vectorize"
#   [43] "vector"                             "vapply"
#   [45] "utf8ToInt"                          ".userHooksEnv"
#   [47] "UseMethod"                          "url"
#   [49] "upper.tri"                          "unz"
#   [51] "untracemem"                         "untrace"
#   [53] "unsplit"                            "unserialize"
#   [55] "unname"                             "unlockBinding"
#   [57] "unloadNamespace"                    "unlist"
#   [59] "unlink"                             "unix.time"
#   [61] "units.difftime"                     "units<-.difftime"
#   [63] "units<-"                            "units"
#   [65] "unique.warnings"                    "unique.POSIXlt"
#   [67] "unique.numeric_version"             "unique.matrix"
#   [69] "unique.default"                     "unique.data.frame"
#   [71] "unique.array"                       "unique"
#   [73] "union"                              "undebug"
#   [75] "unclass"                            "typeof"
#   [77] "tryCatch"                           "try"
#   [79] "trunc.POSIXt"                       "trunc.Date"
#   [81] "truncate.connection"                "truncate"
#   [83] "trunc"                              "trimws"
#   [85] "trigamma"                           "transform.default"
#   [87] "transform.data.frame"               "transform"
#   [89] "tracingState"                       "tracemem"
#   [91] "traceback"                          "trace"
#   [93] "toupper"                            "toString.default"
#   [95] "toString"                           "topenv"
#   [97] "tolower"                            "textConnectionValue"
#   [99] "textConnection"                     "testPlatformEquivalence"
#  [101] "tempfile"                           "tempdir"
#  [103] "t.default"                          "t.data.frame"
#  [105] "tcrossprod"                         "taskCallbackManager"
#  [107] "tapply"                             ".TAOCP1997init"
#  [109] "tanpi"                              "tanh"
#  [111] "tan"                                "tabulate"
#  [113] "table"                              "T"
#  [115] "t"                                  "Sys.which"
#  [117] "Sys.unsetenv"                       "Sys.umask"
#  [119] "Sys.timezone"                       "Sys.time"
#  [121] "system.time"                        "system.file"
#  [123] "system2"                            "system"
#  [125] "sys.status"                         "sys.source"
#  [127] "Sys.sleep"                          "Sys.setlocale"
#  [129] "Sys.setFileTime"                    "Sys.setenv"
#  [131] "sys.save.image"                     "Sys.readlink"
#  [133] "sys.parents"                        "sys.parent"
#  [135] "sys.on.exit"                        "sys.nframe"
#  [137] "Sys.localeconv"                     "sys.load.image"
#  [139] "Sys.info"                           "Sys.glob"
#  [141] "Sys.getpid"                         "Sys.getlocale"
#  [143] "Sys.getenv"                         "sys.function"
#  [145] "sys.frames"                         "sys.frame"
#  [147] "Sys.Date"                           "Sys.chmod"
#  [149] "sys.calls"                          "sys.call"
#  [151] "switch"                             "sweep"
#  [153] "svd"                                "suppressWarnings"
#  [155] "suppressPackageStartupMessages"     "suppressMessages"
#  [157] "summary.table"                      "summary.srcref"
#  [159] "summary.srcfile"                    "summary.proc_time"
#  [161] "Summary.POSIXlt"                    "summary.POSIXlt"
#  [163] "Summary.POSIXct"                    "summary.POSIXct"
#  [165] "Summary.ordered"                    "Summary.numeric_version"
#  [167] "summary.matrix"                     "Summary.factor"
#  [169] "summary.factor"                     "Summary.difftime"
#  [171] "summary.default"                    "Summary.Date"
#  [173] "summary.Date"                       "Summary.data.frame"
#  [175] "summary.data.frame"                 "summary.connection"
#  [177] "summary"                            "sum"
#  [179] "substring<-"                        "substring"
#  [181] "substr<-"                           "substr"
#  [183] "substitute"                         "subset.matrix"
#  [185] "subset.default"                     "subset.data.frame"
#  [187] ".subset2"                           ".subset"
#  [189] "subset"                             "sub"
#  [191] "strwrap"                            "structure"
#  [193] "strtrim"                            "strtoi"
#  [195] "strsplit"                           "strptime"
#  [197] "strftime"                           "storage.mode<-"
#  [199] "storage.mode"                       "stopifnot"
#  [201] "stop"                               "stdout"
#  [203] "stdin"                              "stderr"
#  [205] ".standard_regexps"                  "standardGeneric"
#  [207] "srcref"                             "srcfilecopy"
#  [209] "srcfilealias"                       "srcfile"
#  [211] "sQuote"                             "sqrt"
#  [213] "sprintf"                            "split.POSIXct"
#  [215] "split.default"                      "split<-.default"
#  [217] "split.Date"                         "split.data.frame"
#  [219] "split<-.data.frame"                 "split<-"
#  [221] "split"                              "source"
#  [223] "sort.POSIXlt"                       "sort.list"
#  [225] "sort.int"                           "sort.default"
#  [227] "sort"                               "solve.qr"
#  [229] "solve.default"                      "solve"
#  [231] "socketSelect"                       "socketConnection"
#  [233] "slice.index"                        "sinpi"
#  [235] "sink.number"                        "sink"
#  [237] "sinh"                               "single"
#  [239] "sin"                                "simplify2array"
#  [241] "simpleWarning"                      "simpleMessage"
#  [243] "[.simple.list"                      "simpleError"
#  [245] "simpleCondition"                    "signif"
#  [247] ".signalSimpleWarning"               "signalCondition"
#  [249] "sign"                               "shQuote"
#  [251] "showConnections"                    "setwd"
#  [253] "setTimeLimit"                       "setSessionTimeLimit"
#  [255] "set.seed"                           ".set_row_names"
#  [257] "setNamespaceInfo"                   "setHook"
#  [259] "setequal"                           "setdiff"
#  [261] "serialize"                          "sequence"
#  [263] "seq.POSIXt"                         "seq_len"
#  [265] "seq.int"                            "seq.default"
#  [267] "seq.Date"                           "seq_along"
#  [269] "seq"                                "seek.connection"
#  [271] "seek"                               "searchpaths"
#  [273] "search"                             ".Script"
#  [275] "scan"                               "scale.default"
#  [277] "scale"                              ".saveRDS"
#  [279] "saveRDS"                            "save.image"
#  [281] "save"                               "sapply"
#  [283] "sample.int"                         "sample"
#  [285] ".S3PrimitiveGenerics"               ".__S3MethodsTable__."
#  [287] "R.version.string"                   "R.Version"
#  [289] "R.version"                          "R_system_version"
#  [291] ".rowSums"                           "rowSums"
#  [293] "rowsum.default"                     "rowsum.data.frame"
#  [295] "rowsum"                             ".row_names_info"
#  [297] "row.names.default"                  "row.names<-.default"
#  [299] "row.names.data.frame"               "row.names<-.data.frame"
#  [301] "rownames<-"                         "row.names<-"
#  [303] "row.names"                          "rownames"
#  [305] ".rowMeans"                          "rowMeans"
#  [307] "row"                                "round.POSIXt"
#  [309] "round.Date"                         "round"
#  [311] "RNGversion"                         "RNGkind"
#  [313] "rm"                                 "rle"
#  [315] "R.home"                             "rev.default"
#  [317] "rev"                                "returnValue"
#  [319] "return"                             "retracemem"
#  [321] "restartFormals"                     "restartDescription"
#  [323] "requireNamespace"                   "require"
#  [325] "rep.POSIXlt"                        "rep.POSIXct"
#  [327] "rep.numeric_version"                "replicate"
#  [329] "rep_len"                            "replace"
#  [331] "rep.int"                            "rep.factor"
#  [333] "repeat"                             "rep.Date"
#  [335] "rep"                                "removeTaskCallback"
#  [337] "remove"                             "regmatches<-"
#  [339] "regmatches"                         "registerS3methods"
#  [341] "registerS3method"                   "reg.finalizer"
#  [343] "regexpr"                            "regexec"
#  [345] "Reduce"                             "Recall"
#  [347] "readRenviron"                       ".readRDS"
#  [349] "readRDS"                            "readLines"
#  [351] "readline"                           "read.dcf"
#  [353] "readChar"                           "readBin"
#  [355] "Re"                                 "rcond"
#  [357] "rbind.data.frame"                   "rbind"
#  [359] "rawToChar"                          "rawToBits"
#  [361] "rawShift"                           "rawConnectionValue"
#  [363] "rawConnection"                      "raw"
#  [365] "rapply"                             "rank"
#  [367] "range.default"                      "range"
#  [369] "quote"                              "quit"
#  [371] "quarters.POSIXt"                    "quarters.Date"
#  [373] "quarters"                           "qr.X"
#  [375] "qr.solve"                           "qr.resid"
#  [377] "qr.R"                               "qr.qy"
#  [379] "qr.qty"                             "qr.Q"
#  [381] "qr.fitted"                          "qr.default"
#  [383] "qr.coef"                            "qr"
#  [385] "q"                                  "pushBackLength"
#  [387] "pushBack"                           "psigamma"
#  [389] "provideDimnames"                    "prop.table"
#  [391] "prod"                               "proc.time"
#  [393] "prmatrix"                           "print.warnings"
#  [395] "print.table"                        "print.summary.table"
#  [397] "print.summaryDefault"               "print.srcref"
#  [399] "print.srcfile"                      "print.simple.list"
#  [401] "print.rle"                          "print.restart"
#  [403] "print.proc_time"                    "print.POSIXlt"
#  [405] "print.POSIXct"                      "print.packageInfo"
#  [407] "print.octmode"                      "print.numeric_version"
#  [409] "print.noquote"                      "print.NativeRoutineList"
#  [411] "print.listof"                       "print.libraryIQR"
#  [413] "print.hexmode"                      "print.function"
#  [415] "print.factor"                       "print.DLLRegisteredRoutines"
#  [417] "print.DLLInfoList"                  "print.DLLInfo"
#  [419] "print.Dlist"                        "print.difftime"
#  [421] "print.default"                      "print.Date"
#  [423] "print.data.frame"                   "print.connection"
#  [425] "print.condition"                    "print.by"
#  [427] "print.AsIs"                         "print"
#  [429] ".primUntrace"                       ".primTrace"
#  [431] ".Primitive"                         "prettyNum"
#  [433] "pretty.default"                     "pretty"
#  [435] "pos.to.env"                         "+.POSIXt"
#  [437] "-.POSIXt"                           "[.POSIXlt"
#  [439] "[<-.POSIXlt"                        ".POSIXlt"
#  [441] "[[.POSIXct"                         "[.POSIXct"
#  [443] "[<-.POSIXct"                        ".POSIXct"
#  [445] "Position"                           ".popath"
#  [447] "polyroot"                           "pmin.int"
#  [449] "pmin"                               "pmax.int"
#  [451] "pmax"                               "pmatch"
#  [453] ".Platform"                          "pipe"
#  [455] "pi"                                 "pcre_config"
#  [457] "path.package"                       ".path.package"
#  [459] "path.expand"                        "paste0"
#  [461] "paste"                              "parseNamespaceFile"
#  [463] "parse"                              "parent.frame"
#  [465] "parent.env<-"                       "parent.env"
#  [467] "pairlist"                           "packBits"
#  [469] "package_version"                    "$.package_version"
#  [471] ".packageStartupMessage"             "packageStartupMessage"
#  [473] ".packages"                          "packageHasNamespace"
#  [475] "packageEvent"                       "outer"
#  [477] "ordered"                            "order"
#  [479] ".OptRequireMethods"                 ".Options"
#  [481] "options"                            "Ops.POSIXt"
#  [483] "Ops.ordered"                        "Ops.numeric_version"
#  [485] "Ops.factor"                         "Ops.difftime"
#  [487] "Ops.Date"                           "Ops.data.frame"
#  [489] "open.srcfilecopy"                   "open.srcfilealias"
#  [491] "open.srcfile"                       "open.connection"
#  [493] "open"                               "on.exit"
#  [495] "OlsonNames"                         "oldClass<-"
#  [497] "oldClass"                           "&.octmode"
#  [499] "[.octmode"                          "!.octmode"
#  [501] "|.octmode"                          "objects"
#  [503] "%o%"                                "nzchar"
#  [505] "numeric_version"                    "[[.numeric_version"
#  [507] "[[<-.numeric_version"               "[.numeric_version"
#  [509] "[<-.numeric_version"                "numeric"
#  [511] "NROW"                               "nrow"
#  [513] ".NotYetUsed"                        ".NotYetImplemented"
#  [515] "normalizePath"                      "norm"
#  [517] "[.noquote"                          "noquote"
#  [519] ".noGenerics"                        "nlevels"
#  [521] "ngettext"                           "NextMethod"
#  [523] "next"                               "new.env"
#  [525] "Negate"                             "NCOL"
#  [527] "ncol"                               "nchar"
#  [529] "nargs"                              "names.POSIXlt"
#  [531] "names<-.POSIXlt"                    "namespaceImportMethods"
#  [533] "namespaceImportFrom"                "namespaceImportClasses"
#  [535] "namespaceImport"                    "namespaceExport"
#  [537] "names<-"                            "names"
#  [539] "mostattributes<-"                   "months.POSIXt"
#  [541] "months.Date"                        "months"
#  [543] "month.name"                         "month.abb"
#  [545] "mode<-"                             "mode"
#  [547] "Mod"                                "missing"
#  [549] "min"                                "mget"
#  [551] ".methodsNamespace"                  "message"
#  [553] ".mergeImportMethods"                ".mergeExportMethods"
#  [555] "merge.default"                      "merge.data.frame"
#  [557] "merge"                              "memory.profile"
#  [559] "mem.limits"                         "memDecompress"
#  [561] "memCompress"                        "mean.POSIXlt"
#  [563] "mean.POSIXct"                       "mean.difftime"
#  [565] "mean.default"                       "mean.Date"
#  [567] "mean"                               "max.col"
#  [569] "max"                                "matrix"
#  [571] "mat.or.vec"                         "Math.POSIXt"
#  [573] "Math.factor"                        "Math.difftime"
#  [575] "Math.Date"                          "Math.data.frame"
#  [577] "match.fun"                          "match.call"
#  [579] "match.arg"                          "match"
#  [581] ".maskedMsg"                         "margin.table"
#  [583] ".mapply"                            "mapply"
#  [585] "Map"                                "make.unique"
#  [587] ".make_numeric_version"              "make.names"
#  [589] ".makeMessage"                       "makeActiveBinding"
#  [591] ".Machine"                           "ls"
#  [593] "lower.tri"                          "logical"
#  [595] "logb"                               "log2"
#  [597] "log1p"                              "log10"
#  [599] "log"                                "lockEnvironment"
#  [601] "lockBinding"                        "local"
#  [603] "loadNamespace"                      "loadingNamespaceInfo"
#  [605] "loadedNamespaces"                   "load"
#  [607] "[.listof"                           "list.files"
#  [609] "list.dirs"                          "list2env"
#  [611] "list"                               "license"
#  [613] "licence"                            ".Library.site"
#  [615] "library.dynam.unload"               "library.dynam"
#  [617] ".Library"                           "library"
#  [619] ".libPaths"                          "libcurlVersion"
#  [621] "lgamma"                             "lfactorial"
#  [623] "levels<-.factor"                    "levels.default"
#  [625] "levels<-"                           "levels"
#  [627] "LETTERS"                            "letters"
#  [629] "lengths"                            "length.POSIXlt"
#  [631] "length<-.factor"                    "length<-"
#  [633] "length"                             ".leap.seconds"
#  [635] "lchoose"                            "lbeta"
#  [637] "lazyLoadDBfetch"                    "lazyLoadDBexec"
#  [639] "lazyLoad"                           "La_version"
#  [641] "La.svd"                             ".Last.value"
#  [643] "lapply"                             "labels.default"
#  [645] "labels"                             "l10n_info"
#  [647] ".kronecker"                         "kronecker"
#  [649] ".knownS3Generics"                   ".kappa_tri"
#  [651] "kappa.qr"                           "kappa.lm"
#  [653] "kappa.default"                      "kappa"
#  [655] "julian.POSIXt"                      "julian.Date"
#  [657] "julian"                             "jitter"
#  [659] "is.vector"                          "is.unsorted"
#  [661] "isTRUE"                             "is.table"
#  [663] "isSymmetric.matrix"                 "isSymmetric"
#  [665] "is.symbol"                          "is.single"
#  [667] "isSeekable"                         "isS4"
#  [669] "isRestart"                          "is.recursive"
#  [671] "is.raw"                             "is.R"
#  [673] "is.qr"                              "is.primitive"
#  [675] "is.pairlist"                        "is.package_version"
#  [677] "is.ordered"                         ".isOpen"
#  [679] "isOpen"                             "ISOdatetime"
#  [681] "ISOdate"                            "is.object"
#  [683] "is.numeric_version"                 "is.numeric.POSIXt"
#  [685] "is.numeric.difftime"                "is.numeric.Date"
#  [687] "is.numeric"                         "is.null"
#  [689] "is.na.POSIXlt"                      "is.na.numeric_version"
#  [691] "is.na<-.numeric_version"            "is.nan"
#  [693] "isNamespaceLoaded"                  "isNamespace"
#  [695] "is.name"                            "is.na<-.factor"
#  [697] "is.na<-.default"                    "is.na.data.frame"
#  [699] "is.na<-"                            "is.na"
#  [701] ".isMethodsDispatchOn"               "is.matrix"
#  [703] "is.logical"                         "is.loaded"
#  [705] "is.list"                            "is.language"
#  [707] "is.integer"                         "is.infinite"
#  [709] "isIncomplete"                       "is.function"
#  [711] "is.finite"                          "is.factor"
#  [713] "is.expression"                      "is.environment"
#  [715] "is.element"                         "is.double"
#  [717] "isdebugged"                         "is.data.frame"
#  [719] "is.complex"                         "is.character"
#  [721] "is.call"                            "isBaseNamespace"
#  [723] "isatty"                             "is.atomic"
#  [725] "is.array"                           "invokeRestartInteractively"
#  [727] "invokeRestart"                      "invisible"
#  [729] "inverse.rle"                        "intToUtf8"
#  [731] "intToBits"                          "intersect"
#  [733] ".Internal"                          "interactive"
#  [735] "interaction"                        "integer"
#  [737] "inherits"                           "%in%"
#  [739] "importIntoEnv"                      "Im"
#  [741] "ifelse"                             "if"
#  [743] "identity"                           "identical"
#  [745] "icuSetCollate"                      "icuGetCollate"
#  [747] "iconvlist"                          "iconv"
#  [749] "I"                                  ".__H__.rbind"
#  [751] "&.hexmode"                          "[.hexmode"
#  [753] "!.hexmode"                          "|.hexmode"
#  [755] ".__H__.cbind"                       ".handleSimpleError"
#  [757] "gzfile"                             "gzcon"
#  [759] ".gtn"                               ".gt"
#  [761] "gsub"                               "grepRaw"
#  [763] "grepl"                              "grep"
#  [765] "gregexpr"                           ".GlobalEnv"
#  [767] "globalenv"                          "gl"
#  [769] "getwd"                              "gettextf"
#  [771] "gettext"                            "getTaskCallbackNames"
#  [773] "getSrcLines"                        "getRversion"
#  [775] ".getRequiredPackages2"              ".getRequiredPackages"
#  [777] "getOption"                          "getNativeSymbolInfo"
#  [779] "getNamespaceVersion"                "getNamespaceUsers"
#  [781] "getNamespaceName"                   ".getNamespaceInfo"
#  [783] "getNamespaceInfo"                   "getNamespaceImports"
#  [785] "getNamespaceExports"                "..getNamespace"
#  [787] ".getNamespace"                      "getNamespace"
#  [789] "getLoadedDLLs"                      "getHook"
#  [791] "getExportedValue"                   "geterrmessage"
#  [793] "getElement"                         "getDLLRegisteredRoutines.DLLInfo"
#  [795] "getDLLRegisteredRoutines.character" "getDLLRegisteredRoutines"
#  [797] "getConnection"                      "getCallingDLLe"
#  [799] "getCallingDLL"                      "getAllConnections"
#  [801] "get0"                               "get"
#  [803] ".GenericArgsEnv"                    "gctorture2"
#  [805] "gctorture"                          "gc.time"
#  [807] "gcinfo"                             "gc"
#  [809] "gamma"                              "function"
#  [811] "forwardsolve"                       ".Fortran"
#  [813] ".format.zeros"                      "format.summaryDefault"
#  [815] "format.pval"                        "format.POSIXlt"
#  [817] "format.POSIXct"                     "format.packageInfo"
#  [819] "format.octmode"                     "format.numeric_version"
#  [821] "format.libraryIQR"                  "format.info"
#  [823] "format.hexmode"                     "format.factor"
#  [825] "formatDL"                           "format.difftime"
#  [827] "format.default"                     "format.Date"
#  [829] "format.data.frame"                  "formatC"
#  [831] "format.AsIs"                        "format"
#  [833] "formals<-"                          "formals"
#  [835] "forceAndCall"                       "force"
#  [837] "for"                                "flush.connection"
#  [839] "flush"                              "floor"
#  [841] ".First.sys"                         "findRestart"
#  [843] "findPackageEnv"                     "find.package"
#  [845] ".find.package"                      "findInterval"
#  [847] "Find"                               "Filter"
#  [849] "file.symlink"                       "file.size"
#  [851] "file.show"                          "file.rename"
#  [853] "file.remove"                        "file.path"
#  [855] "file.mtime"                         "file.mode"
#  [857] "file.link"                          "file.info"
#  [859] "file.exists"                        "file.create"
#  [861] "file.copy"                          "file.choose"
#  [863] "file.append"                        "file.access"
#  [865] "file"                               "fifo"
#  [867] ".F_dtrco"                           ".F_dqrxb"
#  [869] ".F_dqrrsd"                          ".F_dqrqy"
#  [871] ".F_dqrqty"                          ".F_dqrdc2"
#  [873] ".F_dqrcf"                           ".F_dchdc"
#  [875] "factorial"                          "[[.factor"
#  [877] "[[<-.factor"                        "[.factor"
#  [879] "[<-.factor"                         "factor"
#  [881] "F"                                  "extSoftVersion"
#  [883] ".External.graphics"                 ".External2"
#  [885] ".External"                          "expression"
#  [887] "expm1"                              ".expand_R_libs_env_var"
#  [889] "expand.grid"                        "exp"
#  [891] "exists"                             "evalq"
#  [893] "eval.parent"                        "eval"
#  [895] "env.profile"                        "environmentName"
#  [897] "environmentIsLocked"                "environment<-"
#  [899] "environment"                        "enquote"
#  [901] "Encoding<-"                         "Encoding"
#  [903] "encodeString"                       ".encode_numeric_version"
#  [905] "enc2utf8"                           "enc2native"
#  [907] "emptyenv"                           "eigen"
#  [909] "eapply"                             "dyn.unload"
#  [911] "dyn.load"                           ".dynLibs"
#  [913] "dynGet"                             "duplicated.POSIXlt"
#  [915] "duplicated.numeric_version"         "duplicated.matrix"
#  [917] "duplicated.default"                 "duplicated.data.frame"
#  [919] "duplicated.array"                   "duplicated"
#  [921] "dump"                               "droplevels.factor"
#  [923] "droplevels.data.frame"              "droplevels"
#  [925] "drop"                               "dQuote"
#  [927] "dput"                               "double"
#  [929] ".doTrace"                           "dontCheck"
#  [931] "do.call"                            "$.DLLInfo"
#  [933] "[.Dlist"                            "dirname"
#  [935] "dir.exists"                         "dir.create"
#  [937] "dir"                                "dimnames.data.frame"
#  [939] "dimnames<-.data.frame"              "dimnames<-"
#  [941] "dimnames"                           "dim.data.frame"
#  [943] "dim<-"                              "dim"
#  [945] "digamma"                            "*.difftime"
#  [947] "[.difftime"                         ".difftime"
#  [949] "/.difftime"                         "difftime"
#  [951] "diff.POSIXt"                        "diff.default"
#  [953] "diff.Date"                          "diff"
#  [955] "diag<-"                             "diag"
#  [957] "dget"                               ".Devices"
#  [959] ".Device"                            "determinant.matrix"
#  [961] "determinant"                        ".detach"
#  [963] "detach"                             "det"
#  [965] ".Deprecated"                        ".deparseOpts"
#  [967] "deparse"                            "delayedAssign"
#  [969] ".Defunct"                           "default.stringsAsFactors"
#  [971] ".decode_numeric_version"            "debugonce"
#  [973] "debuggingState"                     "debug"
#  [975] "+.Date"                             "[[.Date"
#  [977] "[.Date"                             "[<-.Date"
#  [979] "-.Date"                             "date"
#  [981] "data.matrix"                        "data.frame"
#  [983] "$.data.frame"                       "$<-.data.frame"
#  [985] "[[.data.frame"                      "[[<-.data.frame"
#  [987] "[.data.frame"                       "[<-.data.frame"
#  [989] "data.class"                         "c.warnings"
#  [991] "cut.POSIXt"                         "cut.default"
#  [993] "cut.Date"                           "cut"
#  [995] "curlGetHeaders"                     "cumsum"
#  [997] "cumprod"                            "cummin"
#  [999] "cummax"                             "Cstack_info"
# [1001] ".C_R_removeTaskCallback"            "crossprod"
# [1003] ".C_R_getTaskCallbackNames"          ".C_R_addTaskCallback"
# [1005] "c.POSIXlt"                          "c.POSIXct"
# [1007] "cospi"                              "cosh"
# [1009] "cos"                                "contributors"
# [1011] "Conj"                               "conflicts"
# [1013] "conditionMessage.condition"         "conditionMessage"
# [1015] "conditionCall.condition"            "conditionCall"
# [1017] "computeRestarts"                    "complex"
# [1019] "comment<-"                          "comment"
# [1021] "commandArgs"                        ".colSums"
# [1023] "colSums"                            "colnames<-"
# [1025] "colnames"                           ".colMeans"
# [1027] "colMeans"                           "col"
# [1029] "c.numeric_version"                  "c.noquote"
# [1031] "close.srcfilealias"                 "close.srcfile"
# [1033] "close.connection"                   "closeAllConnections"
# [1035] "close"                              "clearPushBack"
# [1037] "class<-"                            "class"
# [1039] "choose"                             "chol.default"
# [1041] "chol2inv"                           "chol"
# [1043] "check_tzones"                       "chartr"
# [1045] "charToRaw"                          "charmatch"
# [1047] "char.expand"                        "character"
# [1049] "ceiling"                            "c.Date"
# [1051] "cbind.data.frame"                   "cbind"
# [1053] "cat"                                "casefold"
# [1055] "capabilities"                       ".Call.graphics"
# [1057] "callCC"                             ".Call"
# [1059] "call"                               ".cache_class"
# [1061] ".C"                                 "c"
# [1063] "bzfile"                             "by.default"
# [1065] "by.data.frame"                      "by"
# [1067] "builtins"                           "browserText"
# [1069] "browserSetDebug"                    "browserCondition"
# [1071] "browser"                            "break"
# [1073] "bquote"                             "body<-"
# [1075] "body"                               "bitwXor"
# [1077] "bitwShiftR"                         "bitwShiftL"
# [1079] "bitwOr"                             "bitwNot"
# [1081] "bitwAnd"                            "bindtextdomain"
# [1083] "bindingIsLocked"                    "bindingIsActive"
# [1085] ".bincode"                           "beta"
# [1087] "besselY"                            "besselK"
# [1089] "besselJ"                            "besselI"
# [1091] ".BaseNamespaceEnv"                  "basename"
# [1093] "baseenv"                            "backsolve"
# [1095] "autoloader"                         ".AutoloadEnv"
# [1097] "autoload"                           "attributes<-"
# [1099] "attributes"                         "attr.all.equal"
# [1101] "attr<-"                             "attr"
# [1103] "attachNamespace"                    "attach"
# [1105] "atanh"                              "atan2"
# [1107] "atan"                               "as.vector.factor"
# [1109] "as.vector"                          "as.table.default"
# [1111] "as.table"                           "as.symbol"
# [1113] "as.single.default"                  "as.single"
# [1115] "assign"                             "asS4"
# [1117] "asS3"                               "as.raw"
# [1119] "as.qr"                              "as.POSIXlt.POSIXct"
# [1121] "as.POSIXlt.numeric"                 "as.POSIXlt.factor"
# [1123] "as.POSIXlt.default"                 "as.POSIXlt.dates"
# [1125] "as.POSIXlt.Date"                    "as.POSIXlt.date"
# [1127] "as.POSIXlt.character"               "as.POSIXlt"
# [1129] "as.POSIXct.POSIXlt"                 "as.POSIXct.numeric"
# [1131] "as.POSIXct.default"                 "as.POSIXct.dates"
# [1133] "as.POSIXct.Date"                    "as.POSIXct.date"
# [1135] "as.POSIXct"                         "as.pairlist"
# [1137] "as.package_version"                 "as.ordered"
# [1139] "as.octmode"                         "as.numeric_version"
# [1141] "as.numeric"                         "as.null.default"
# [1143] "as.null"                            "asNamespace"
# [1145] "as.name"                            "as.matrix.POSIXlt"
# [1147] "as.matrix.noquote"                  "as.matrix.default"
# [1149] "as.matrix.data.frame"               "as.matrix"
# [1151] "as.logical.factor"                  "as.logical"
# [1153] "as.list.POSIXct"                    "as.list.numeric_version"
# [1155] "as.list.function"                   "as.list.factor"
# [1157] "as.list.environment"                "as.list.default"
# [1159] "as.list.Date"                       "as.list.data.frame"
# [1161] "as.list"                            "[.AsIs"
# [1163] "as.integer"                         "asinh"
# [1165] "asin"                               "as.hexmode"
# [1167] "as.function.default"                "as.function"
# [1169] "as.factor"                          "as.expression.default"
# [1171] "as.expression"                      "as.environment"
# [1173] "as.double.POSIXlt"                  "as.double.difftime"
# [1175] "as.double"                          "as.difftime"
# [1177] "as.Date.POSIXlt"                    "as.Date.POSIXct"
# [1179] "as.Date.numeric"                    "as.Date.factor"
# [1181] "as.Date.default"                    "as.Date.dates"
# [1183] "as.Date.date"                       "as.Date.character"
# [1185] "as.Date"                            "as.data.frame.vector"
# [1187] "as.data.frame.ts"                   "as.data.frame.table"
# [1189] "as.data.frame.raw"                  "as.data.frame.POSIXlt"
# [1191] "as.data.frame.POSIXct"              "as.data.frame.ordered"
# [1193] "as.data.frame.numeric_version"      "as.data.frame.numeric"
# [1195] "as.data.frame.noquote"              "as.data.frame.model.matrix"
# [1197] "as.data.frame.matrix"               "as.data.frame.logical"
# [1199] "as.data.frame.list"                 "as.data.frame.integer"
# [1201] "as.data.frame.factor"               "as.data.frame.difftime"
# [1203] "as.data.frame.default"              "as.data.frame.Date"
# [1205] "as.data.frame.data.frame"           "as.data.frame.complex"
# [1207] "as.data.frame.character"            "as.data.frame.AsIs"
# [1209] "as.data.frame.array"                "as.data.frame"
# [1211] "as.complex"                         "as.character.srcref"
# [1213] "as.character.POSIXt"                "as.character.octmode"
# [1215] "as.character.numeric_version"       "as.character.hexmode"
# [1217] "as.character.factor"                "as.character.error"
# [1219] "as.character.default"               "as.character.Date"
# [1221] "as.character.condition"             "as.character"
# [1223] "as.call"                            "as.array.default"
# [1225] "as.array"                           "arrayInd"
# [1227] "array"                              ".ArgsEnv"
# [1229] "args"                               "Arg"
# [1231] "apply"                              "append"
# [1233] "aperm.table"                        "aperm.default"
# [1235] "aperm"                              "anyNA.POSIXlt"
# [1237] "anyNA.numeric_version"              "anyNA"
# [1239] "anyDuplicated.matrix"               "anyDuplicated.default"
# [1241] "anyDuplicated.data.frame"           "anyDuplicated.array"
# [1243] "anyDuplicated"                      "any"
# [1245] ".amatch_costs"                      ".amatch_bounds"
# [1247] "all.vars"                           "all.names"
# [1249] "all.equal.raw"                      "all.equal.POSIXt"
# [1251] "all.equal.numeric"                  "all.equal.list"
# [1253] "all.equal.language"                 "all.equal.formula"
# [1255] "all.equal.factor"                   "all.equal.envRefClass"
# [1257] "all.equal.environment"              "all.equal.default"
# [1259] "all.equal.character"                "all.equal"
# [1261] "all"                                "alist"
# [1263] "agrepl"                             "agrep"
# [1265] "addTaskCallback"                    "addNA"
# [1267] "acosh"                              "acos"
# [1269] "abs"                                "abbreviate"
# [1271] "+"                                  "%%"
# [1273] "%*%"                                "%/%"
# [1275] "&&"                                 "&"
# [1277] "*"                                  "$<-"
# [1279] "$"                                  "@<-"
# [1281] "@"                                  "{"
# [1283] "[[<-"                               "[["
# [1285] "[<-"                                "["
# [1287] "("                                  "/"
# [1289] "!="                                 "!"
# [1291] ":::"                                "::"
# [1293] ":"                                  "-"
# [1295] "||"                                 "|"
# [1297] ">="                                 ">"
# [1299] "=="                                 "="
# [1301] "<-"                                 "<="
# [1303] "<<-"                                "<"
# [1305] "~"                                  "^"
